# %%
# !pip install altair==4.0.1
# Out:
# Collecting altair==4.0.1
#   Downloading altair-4.0.1-py3-none-any.whl (708 kB)
# Requirement already satisfied: jsonschema in c:\users\dell\anaconda3\lib\site-packages (from altair==4.0.1) (3.2.0)
# Requirement already satisfied: entrypoints in c:\users\dell\anaconda3\lib\site-packages (from altair==4.0.1) (0.3)
# Requirement already satisfied: jinja2 in c:\users\dell\anaconda3\lib\site-packages (from altair==4.0.1) (2.11.3)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\lib\site-packages (from altair==4.0.1) (1.20.3)
# Requirement already satisfied: pandas in c:\users\dell\anaconda3\lib\site-packages (from altair==4.0.1) (1.3.4)
# Requirement already satisfied: toolz in c:\users\dell\anaconda3\lib\site-packages (from altair==4.0.1) (0.11.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\dell\anaconda3\lib\site-packages (from jinja2->altair==4.0.1) (1.1.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\dell\anaconda3\lib\site-packages (from jsonschema->altair==4.0.1) (0.18.0)
# Requirement already satisfied: setuptools in c:\users\dell\anaconda3\lib\site-packages (from jsonschema->altair==4.0.1) (58.0.4)
# Requirement already satisfied: six>=1.11.0 in c:\users\dell\anaconda3\lib\site-packages (from jsonschema->altair==4.0.1) (1.16.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\dell\anaconda3\lib\site-packages (from jsonschema->altair==4.0.1) (21.2.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\dell\anaconda3\lib\site-packages (from pandas->altair==4.0.1) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\dell\anaconda3\lib\site-packages (from pandas->altair==4.0.1) (2021.3)
# Installing collected packages: altair
#   Attempting uninstall: altair
#     Found existing installation: altair 5.0.1
#     Uninstalling altair-5.0.1:
#       Successfully uninstalled altair-5.0.1
# Successfully installed altair-4.0.1

# %%
import pickle  as cv
print(cv.__version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5708/3615170846.py in <module>
#       1 import pickle  as cv
# ----> 2 print(cv.__version__)
#
# AttributeError: module 'pickle' has no attribute '__version__'

# %%
# !pip install streamlit==1.2.0
# Out:
# Requirement already satisfied: streamlit==1.2.0 in c:\users\dell\anaconda3\lib\site-packages (1.2.0)
# Requirement already satisfied: toml in c:\users\dell\anaconda3\lib\site-packages (from streamlit==1.2.0) (0.10.2)
# Requirement already satisfied: pandas>=0.21.0 in c:\users\dell\anaconda3\lib\site-packages (from streamlit==1.2.0) (1.3.4)
# Requirement already satisfied: pydeck>=0.1.dev5 in c:\users\dell\anaconda3\lib\site-packages (from streamlit==1.2.0) (0.8.1b0)
# Requirement already satisfied: astor in c:\users\dell\anaconda3\lib\site-packages (from streamlit==1.2.0) (0.8.1)
# Requirement already satisfied: blinker in c:\users\dell\anaconda3\lib\site-packages (from streamlit==1.2.0) (1.6.2)
# Requirement already satisfied: tornado>=5.0 in c:\users\dell\anaconda3\lib\site-packages (from streamlit==1.2.0) (6.1)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\lib\site-packages (from streamlit==1.2.0) (1.20.3)
# Requirement already satisfied: watchdog in c:\users\dell\anaconda3\lib\site-packages (from streamlit==1.2.0) (2.1.3)
# Requirement already satisfied: tzlocal in c:\users\dell\anaconda3\lib\site-packages (from streamlit==1.2.0) (5.0.1)
# Requirement already satisfied: python-dateutil in c:\users\dell\anaconda3\lib\site-packages (from streamlit==1.2.0) (2.8.2)
# Requirement already satisfied: base58 in c:\users\dell\anaconda3\lib\site-packages (from streamlit==1.2.0) (2.1.1)
# Requirement already satisfied: gitpython!=3.1.19 in c:\users\dell\anaconda3\lib\site-packages (from streamlit==1.2.0) (3.1.31)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dell\anaconda3\lib\site-packages (from streamlit==1.2.0) (8.4.0)
# Requirement already satisfied: validators in c:\users\dell\anaconda3\lib\site-packages (from streamlit==1.2.0) (0.20.0)
# Requirement already satisfied: altair>=3.2.0 in c:\users\dell\anaconda3\lib\site-packages (from streamlit==1.2.0) (5.0.1)
# Requirement already satisfied: requests in c:\users\dell\anaconda3\lib\site-packages (from streamlit==1.2.0) (2.26.0)
# Requirement already satisfied: attrs in c:\users\dell\anaconda3\lib\site-packages (from streamlit==1.2.0) (21.2.0)
# Requirement already satisfied: pympler>=0.9 in c:\users\dell\anaconda3\lib\site-packages (from streamlit==1.2.0) (1.0.1)
# Requirement already satisfied: packaging in c:\users\dell\anaconda3\lib\site-packages (from streamlit==1.2.0) (21.0)
# Requirement already satisfied: pyarrow in c:\users\dell\anaconda3\lib\site-packages (from streamlit==1.2.0) (12.0.1)
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in c:\users\dell\anaconda3\lib\site-packages (from streamlit==1.2.0) (3.19.6)
# Requirement already satisfied: click<8.0,>=7.0 in c:\users\dell\anaconda3\lib\site-packages (from streamlit==1.2.0) (7.1.2)
# Requirement already satisfied: cachetools>=4.0 in c:\users\dell\anaconda3\lib\site-packages (from streamlit==1.2.0) (5.2.1)
# Requirement already satisfied: toolz in c:\users\dell\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit==1.2.0) (0.11.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in c:\users\dell\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit==1.2.0) (4.7.0)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\dell\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit==1.2.0) (3.2.0)
# Requirement already satisfied: jinja2 in c:\users\dell\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit==1.2.0) (2.11.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\dell\anaconda3\lib\site-packages (from gitpython!=3.1.19->streamlit==1.2.0) (4.0.10)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\dell\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit==1.2.0) (5.0.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\dell\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.2.0) (1.16.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\dell\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.2.0) (0.18.0)
# Requirement already satisfied: setuptools in c:\users\dell\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.2.0) (58.0.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\dell\anaconda3\lib\site-packages (from pandas>=0.21.0->streamlit==1.2.0) (2021.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\dell\anaconda3\lib\site-packages (from jinja2->altair>=3.2.0->streamlit==1.2.0) (1.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\dell\anaconda3\lib\site-packages (from packaging->streamlit==1.2.0) (3.0.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from requests->streamlit==1.2.0) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests->streamlit==1.2.0) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests->streamlit==1.2.0) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests->streamlit==1.2.0) (2021.10.8)
# Requirement already satisfied: tzdata in c:\users\dell\anaconda3\lib\site-packages (from tzlocal->streamlit==1.2.0) (2023.3)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\dell\anaconda3\lib\site-packages (from validators->streamlit==1.2.0) (5.1.0)

# %%
import altair as alt
print(alt.__version__)
# Out:
# 5.0.1

# %%
# !pip install streamlit opencv-python numpy matplotlib tensorflow scikit-learn seaborn
# Out:
# Requirement already satisfied: streamlit in c:\users\dell\anaconda3\lib\site-packages (1.12.0)
# Requirement already satisfied: opencv-python in c:\users\dell\anaconda3\lib\site-packages (4.8.0.74)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\lib\site-packages (1.20.3)
# Requirement already satisfied: matplotlib in c:\users\dell\anaconda3\lib\site-packages (3.4.3)
# Requirement already satisfied: tensorflow in c:\users\dell\anaconda3\lib\site-packages (2.11.0)
# Requirement already satisfied: scikit-learn in c:\users\dell\anaconda3\lib\site-packages (0.24.2)
# Requirement already satisfied: seaborn in c:\users\dell\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: pydeck>=0.1.dev5 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (0.8.1b0)
# Requirement already satisfied: altair>=3.2.0 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: semver in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (3.0.1)
# Requirement already satisfied: protobuf<4,>=3.12 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (3.19.6)
# Requirement already satisfied: watchdog in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (2.1.3)
# Requirement already satisfied: cachetools>=4.0 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (5.2.1)
# Requirement already satisfied: packaging>=14.1 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (21.0)
# Requirement already satisfied: toml in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: rich>=10.11.0 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (13.4.2)
# Requirement already satisfied: blinker>=1.0.0 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: validators>=0.2 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (0.20.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (8.4.0)
# Requirement already satisfied: click>=7.0 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (8.0.3)
# Requirement already satisfied: requests>=2.4 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (2.26.0)
# Requirement already satisfied: gitpython!=3.1.19 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (3.1.31)
# Requirement already satisfied: pandas>=0.21.0 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (1.3.4)
# Requirement already satisfied: tzlocal>=1.1 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (4.8.1)
# Requirement already satisfied: python-dateutil in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (4.7.0)
# Requirement already satisfied: pyarrow>=4.0 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (12.0.1)
# Requirement already satisfied: pympler>=0.9 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: tornado>=5.0 in c:\users\dell\anaconda3\lib\site-packages (from streamlit) (6.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.4.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.2.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.12.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.2.0)
# Requirement already satisfied: setuptools in c:\users\dell\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (58.0.4)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.2)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (23.1.4)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.51.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.29.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (15.0.6.1)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\dell\anaconda3\lib\site-packages (from scikit-learn) (1.7.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\dell\anaconda3\lib\site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: jinja2 in c:\users\dell\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (2.11.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\dell\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (3.2.0)
# Requirement already satisfied: toolz in c:\users\dell\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (0.11.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\dell\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.37.0)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\lib\site-packages (from click>=7.0->streamlit) (0.4.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\dell\anaconda3\lib\site-packages (from gitpython!=3.1.19->streamlit) (4.0.10)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\dell\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\dell\anaconda3\lib\site-packages (from importlib-metadata>=1.4->streamlit) (3.6.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\dell\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\dell\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (21.2.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\dell\anaconda3\lib\site-packages (from pandas>=0.21.0->streamlit) (2021.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\dell\anaconda3\lib\site-packages (from jinja2->altair>=3.2.0->streamlit) (1.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (3.2)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dell\anaconda3\lib\site-packages (from rich>=10.11.0->streamlit) (2.15.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\dell\anaconda3\lib\site-packages (from rich>=10.11.0->streamlit) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dell\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->streamlit) (0.1.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\dell\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\dell\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\dell\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.16.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\dell\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\dell\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\dell\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dell\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\dell\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\dell\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\dell\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.2)
# Requirement already satisfied: tzdata in c:\users\dell\anaconda3\lib\site-packages (from tzlocal>=1.1->streamlit) (2023.3)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\dell\anaconda3\lib\site-packages (from validators>=0.2->streamlit) (5.1.0)

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\dell\anaconda3\lib\site-packages (4.8.0.74)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\dell\anaconda3\lib\site-packages (from opencv-python) (1.20.3)

# %%
import numpy as np 
import matplotlib.pyplot as plt
import glob
import cv2

import tensorflow as tf
from tensorflow import keras

import random

from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization
import os
import seaborn as sns

import os
import cv2
import numpy as np

def load_images(file_paths):
    images = []
    for file_path in file_paths:
        image = cv2.imread(file_path)
        images.append(image)
    return np.array(images)

categories = ['dry', 'wet']

for category in categories:
    folder_path = f'waste/train/{category}/'
    file_paths = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.jpg')]
    
    if len(file_paths) > 0:
        images = load_images(file_paths)
        for i, image in enumerate(images):
            max_value = np.max(image)
            print(f"Maximum value in {category} image {i+1}: {max_value}")
    else:
        print(f"No images found in {category} category.")



print(os.listdir("waste"))

SIZE = 128

train_images = []
train_labels = [] 
for directory_path in glob.glob("waste\\train\\*"):
    label = directory_path.split("\\")[-1]
    print(label)
    for img_path in glob.glob(os.path.join(directory_path, "*.jpg")):
        print(img_path)
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE, SIZE))
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        train_images.append(img)
        train_labels.append(label)
        
train_images = np.array(train_images)
train_labels = np.array(train_labels)


# test
test_images = []
test_labels = [] 
for directory_path in glob.glob("waste\\test\\*"):
    fruit_label = directory_path.split("\\")[-1]
    for img_path in glob.glob(os.path.join(directory_path, "*.jpg")):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)
        img = cv2.resize(img, (SIZE, SIZE))
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        test_images.append(img)
        test_labels.append(fruit_label)
        
test_images = np.array(test_images)
test_labels = np.array(test_labels)

#Encode labels from text to integers.
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(test_labels)
test_labels_encoded = le.transform(test_labels)
le.fit(train_labels)
train_labels_encoded = le.transform(train_labels)

#Split data into test and train datasets (already split but assigning to meaningful convention)
x_train, y_train, x_test, y_test = train_images, train_labels_encoded, test_images, test_labels_encoded

###################################################################
# Normalize pixel values to between 0 and 1
x_train, x_test = x_train / 255.0, x_test / 255.0

#One hot encode y values for neural network. 
from tensorflow.keras.utils import to_categorical
y_train_one_hot = to_categorical(y_train)
y_test_one_hot = to_categorical(y_test)

#############################

activation = 'sigmoid'

feature_extractor = Sequential()
feature_extractor.add(Conv2D(32, 3, activation = activation, padding = 'same', input_shape = (SIZE, SIZE, 3)))
feature_extractor.add(BatchNormalization())

feature_extractor.add(Conv2D(32, 3, activation = activation, padding = 'same', kernel_initializer = 'he_uniform'))
feature_extractor.add(BatchNormalization())
feature_extractor.add(MaxPooling2D())

feature_extractor.add(Conv2D(64, 3, activation = activation, padding = 'same', kernel_initializer = 'he_uniform'))
feature_extractor.add(BatchNormalization())

feature_extractor.add(Conv2D(64, 3, activation = activation, padding = 'same', kernel_initializer = 'he_uniform'))
feature_extractor.add(BatchNormalization())
feature_extractor.add(MaxPooling2D())

feature_extractor.add(Flatten())

#Add layers for deep learning prediction
x = feature_extractor.output  
x = Dense(128, activation = activation, kernel_initializer = 'he_uniform')(x)
prediction_layer = Dense(2, activation = 'softmax')(x)
                        #2number of classes
# Make a new model combining both feature extractor and x
cnn_model = Model(inputs=feature_extractor.input, outputs=prediction_layer)
cnn_model.compile(optimizer='rmsprop',loss = 'categorical_crossentropy', metrics = ['accuracy'])
print(cnn_model.summary()) 

##########################################
#Train the CNN model
history = cnn_model.fit(x_train, y_train_one_hot, epochs=50, validation_data = (x_test, y_test_one_hot), use_multiprocessing = False)


#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()


prediction_NN = cnn_model.predict(x_test)
prediction_NN = np.argmax(prediction_NN, axis=-1)
prediction_NN = le.inverse_transform(prediction_NN)

#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_labels, prediction_NN)
print(cm)
sns.heatmap(cm, annot=True)

#Check results on a few select images

#n=5 dog park. NN not as good as RF.
n=random.randint(0,20) #Select the index of image to be loaded for testing
img = x_test[n]
plt.imshow(img)
input_img = np.expand_dims(img, axis=0) #Expand dims so the input is (num images, x, y, c)
prediction = np.argmax(cnn_model.predict(input_img))  #argmax to convert categorical back to original
prediction = le.inverse_transform([prediction])  #Reverse the label encoder to original name
print("The prediction for this image is: ", prediction)
print("The actual label for this image is: ", test_labels[n])

################################
#Now, let us use features from convolutional network for RF
X_for_RF = feature_extractor.predict(x_train) #This is out X input to RF

#RANDOM FOREST
from sklearn.ensemble import RandomForestClassifier
RF_model = RandomForestClassifier(n_estimators = 100, random_state = 42)

# Train the model on training data
RF_model.fit(X_for_RF, y_train) #For sklearn no one hot encoding

#Send test data through same feature extractor process
X_test_feature = feature_extractor.predict(x_test)
#Now predict using the trained RF model. 
prediction_RF = RF_model.predict(X_test_feature)
#Inverse le transform to get original label back. 
prediction_RF = le.inverse_transform(prediction_RF)

#Print overall accuracy
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, prediction_RF))

#Confusion Matrix - verify accuracy of each class
cm = confusion_matrix(test_labels, prediction_RF)
#print(cm)
sns.heatmap(cm, annot=True)

#Check results on a few select images
#n=5 #dog park. RF works better than CNN
n=random.randint(0,20) #Select the index of image to be loaded for testing
img = x_test[n]
plt.imshow(img)
input_img = np.expand_dims(img, axis=0) #Expand dims so the input is (num images, x, y, c)
input_img_features=feature_extractor.predict(input_img)
prediction_RF = RF_model.predict(input_img_features)[0] 
prediction_RF = le.inverse_transform([prediction_RF])  #Reverse the label encoder to original name
print("The prediction for this image is: ", prediction_RF)
print("The actual label for this image is: ", test_labels[n])

#save deep learning model
filename="waste_deep.h5"
cnn_model.save(filename)

# save the ml model to disk
import pickle
filename1 = 'waste_ml_model.sav'
pickle.dump(RF_model, open(filename1, 'wb'))


loaded_model = pickle.load(open(filename1, 'rb'))


# test
test_images = []
test_labels = [] 
for directory_path in glob.glob("waste\\test\\*"):
    fruit_label = directory_path.split("\\")[-1]
    for img_path in glob.glob(os.path.join(directory_path, "*.jpg")):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)
        img = cv2.resize(img, (SIZE, SIZE))
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        test_images.append(img)
        test_labels.append(fruit_label)
        
test_images = np.array(test_images)
test_labels = np.array(test_labels)

#Encode labels from text to integers.
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(test_labels)
test_labels_encoded = le.transform(test_labels)
le.fit(train_labels)
train_labels_encoded = le.transform(train_labels)

#Split data into test and train datasets (already split but assigning to meaningful convention)
x_train, y_train, x_test, y_test = train_images, train_labels_encoded, test_images, test_labels_encoded
#Check results on a few select images
#n=5 #dog park. RF works better than CNN
n=random.randint(0,20) #Select the index of image to be loaded for testing
img = x_test[n]
plt.imshow(img)
input_img = np.expand_dims(img, axis=0) #Expand dims so the input is (num images, x, y, c)
input_img_features=feature_extractor.predict(input_img)
prediction_RF = loaded_model.predict(input_img_features)[0] 
prediction_RF = le.inverse_transform([prediction_RF])  #Reverse the label encoder to original name
print("The prediction for this image is: ", prediction_RF)
print("The actual label for this image is: ", test_labels[n])
# Out:
# C:\Users\Dell\AppData\Local\Temp/ipykernel_16072/2222071236.py:26: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(images)
# Maximum value in dry image 1: 255
# Maximum value in dry image 2: 255
# Maximum value in dry image 3: 255
# Maximum value in dry image 4: 255
# Maximum value in dry image 5: 255
# Maximum value in dry image 6: 255
# Maximum value in dry image 7: 255
# Maximum value in dry image 8: 255
# Maximum value in dry image 9: 255
# Maximum value in dry image 10: 255
# Maximum value in dry image 11: 255
# Maximum value in dry image 12: 255
# Maximum value in dry image 13: 255
# Maximum value in dry image 14: 255
# Maximum value in dry image 15: 255
# Maximum value in dry image 16: 255
# Maximum value in dry image 17: 255
# Maximum value in dry image 18: 255
# Maximum value in dry image 19: 255
# Maximum value in dry image 20: 255
# Maximum value in dry image 21: 255
# Maximum value in dry image 22: 255
# Maximum value in dry image 23: 255
# Maximum value in dry image 24: 255
# Maximum value in dry image 25: 255
# Maximum value in dry image 26: 255
# Maximum value in dry image 27: 255
# Maximum value in dry image 28: 255
# Maximum value in dry image 29: 255
# Maximum value in dry image 30: 255
# Maximum value in dry image 31: 255
# Maximum value in dry image 32: 250
# Maximum value in dry image 33: 255
# Maximum value in dry image 34: 255
# Maximum value in dry image 35: 255
# Maximum value in dry image 36: 255
# Maximum value in dry image 37: 255
# Maximum value in dry image 38: 255
# Maximum value in dry image 39: 255
# Maximum value in dry image 40: 255
# Maximum value in dry image 41: 252
# Maximum value in dry image 42: 255
# Maximum value in dry image 43: 255
# Maximum value in dry image 44: 255
# Maximum value in dry image 45: 255
# Maximum value in dry image 46: 255
# Maximum value in dry image 47: 255
# Maximum value in dry image 48: 255
# Maximum value in dry image 49: 255
# Maximum value in dry image 50: 255
# Maximum value in dry image 51: 255
# Maximum value in dry image 52: 255
# Maximum value in dry image 53: 255
# Maximum value in dry image 54: 255
# Maximum value in dry image 55: 255
# Maximum value in dry image 56: 255
# Maximum value in dry image 57: 255
# Maximum value in dry image 58: 255
# Maximum value in dry image 59: 255
# Maximum value in dry image 60: 255
# Maximum value in dry image 61: 255
# Maximum value in dry image 62: 255
# Maximum value in dry image 63: 255
# Maximum value in dry image 64: 255
# Maximum value in dry image 65: 255
# Maximum value in dry image 66: 255
# Maximum value in dry image 67: 255
# Maximum value in dry image 68: 255
# Maximum value in dry image 69: 255
# Maximum value in dry image 70: 255
# Maximum value in dry image 71: 255
# Maximum value in dry image 72: 255
# Maximum value in dry image 73: 255
# Maximum value in dry image 74: 255
# Maximum value in dry image 75: 255
# Maximum value in dry image 76: 255
# Maximum value in dry image 77: 255
# Maximum value in dry image 78: 255
# Maximum value in dry image 79: 255
# Maximum value in dry image 80: 255
# Maximum value in dry image 81: 255
# Maximum value in dry image 82: 255
# Maximum value in dry image 83: 255
# Maximum value in dry image 84: 255
# Maximum value in dry image 85: 255
# Maximum value in dry image 86: 255
# Maximum value in dry image 87: 255
# Maximum value in dry image 88: 255
# Maximum value in dry image 89: 255
# Maximum value in dry image 90: 255
# Maximum value in dry image 91: 255
# Maximum value in dry image 92: 252
# Maximum value in dry image 93: 255
# Maximum value in dry image 94: 255
# Maximum value in dry image 95: 255
# Maximum value in dry image 96: 255
# Maximum value in dry image 97: 255
# Maximum value in dry image 98: 255
# Maximum value in dry image 99: 255
# Maximum value in dry image 100: 255
# Maximum value in dry image 101: 255
# Maximum value in dry image 102: 255
# Maximum value in dry image 103: 255
# Maximum value in dry image 104: 255
# Maximum value in dry image 105: 255
# Maximum value in dry image 106: 255
# Maximum value in dry image 107: 255
# Maximum value in dry image 108: 255
# Maximum value in dry image 109: 255
# Maximum value in dry image 110: 255
# Maximum value in dry image 111: 255
# Maximum value in dry image 112: 255
# Maximum value in dry image 113: 255
# Maximum value in dry image 114: 255
# Maximum value in dry image 115: 255
# Maximum value in dry image 116: 255
# Maximum value in dry image 117: 255
# Maximum value in dry image 118: 255
# Maximum value in dry image 119: 255
# Maximum value in dry image 120: 255
# Maximum value in dry image 121: 255
# Maximum value in dry image 122: 255
# Maximum value in dry image 123: 255
# Maximum value in dry image 124: 255
# Maximum value in dry image 125: 255
# Maximum value in dry image 126: 255
# Maximum value in dry image 127: 255
# Maximum value in dry image 128: 255
# Maximum value in dry image 129: 255
# Maximum value in dry image 130: 255
# Maximum value in dry image 131: 255
# Maximum value in wet image 1: 255
# Maximum value in wet image 2: 255
# Maximum value in wet image 3: 255
# Maximum value in wet image 4: 255
# Maximum value in wet image 5: 255
# Maximum value in wet image 6: 255
# Maximum value in wet image 7: 255
# Maximum value in wet image 8: 255
# Maximum value in wet image 9: 255
# Maximum value in wet image 10: 255
# Maximum value in wet image 11: 255
# Maximum value in wet image 12: 255
# Maximum value in wet image 13: 255
# Maximum value in wet image 14: 255
# Maximum value in wet image 15: 255
# Maximum value in wet image 16: 255
# Maximum value in wet image 17: 255
# Maximum value in wet image 18: 255
# Maximum value in wet image 19: 255
# Maximum value in wet image 20: 255
# Maximum value in wet image 21: 255
# Maximum value in wet image 22: 255
# Maximum value in wet image 23: 255
# Maximum value in wet image 24: 255
# Maximum value in wet image 25: 255
# Maximum value in wet image 26: 255
# Maximum value in wet image 27: 255
# Maximum value in wet image 28: 255
# Maximum value in wet image 29: 255
# Maximum value in wet image 30: 255
# Maximum value in wet image 31: 255
# Maximum value in wet image 32: 255
# Maximum value in wet image 33: 255
# Maximum value in wet image 34: 255
# Maximum value in wet image 35: 255
# Maximum value in wet image 36: 255
# Maximum value in wet image 37: 255
# Maximum value in wet image 38: 255
# Maximum value in wet image 39: 255
# Maximum value in wet image 40: 255
# Maximum value in wet image 41: 255
# Maximum value in wet image 42: 255
# Maximum value in wet image 43: 255
# Maximum value in wet image 44: 255
# Maximum value in wet image 45: 255
# Maximum value in wet image 46: 255
# Maximum value in wet image 47: 255
# Maximum value in wet image 48: 255
# Maximum value in wet image 49: 255
# Maximum value in wet image 50: 255
# Maximum value in wet image 51: 255
# Maximum value in wet image 52: 255
# Maximum value in wet image 53: 255
# Maximum value in wet image 54: 255
# Maximum value in wet image 55: 255
# Maximum value in wet image 56: 255
# Maximum value in wet image 57: 255
# Maximum value in wet image 58: 255
# Maximum value in wet image 156: 255
# Maximum value in wet image 157: 255
# Maximum value in wet image 158: 255
# Maximum value in wet image 159: 255
# Maximum value in wet image 160: 255
# Maximum value in wet image 161: 255
# Maximum value in wet image 162: 255
# Maximum value in wet image 163: 255
# Maximum value in wet image 164: 255
# Maximum value in wet image 165: 255
# Maximum value in wet image 166: 255
# Maximum value in wet image 167: 255
# Maximum value in wet image 168: 255
# Maximum value in wet image 169: 255
# Maximum value in wet image 170: 255
# Maximum value in wet image 171: 255
# Maximum value in wet image 172: 255
# Maximum value in wet image 173: 255
# Maximum value in wet image 174: 255
# Maximum value in wet image 175: 255
# Maximum value in wet image 176: 255
# Maximum value in wet image 177: 255
# Maximum value in wet image 178: 255
# Maximum value in wet image 179: 255
# Maximum value in wet image 180: 255
# Maximum value in wet image 181: 255
# Maximum value in wet image 182: 255
# Maximum value in wet image 183: 255
# Maximum value in wet image 184: 255
# Maximum value in wet image 185: 255
# Maximum value in wet image 186: 255
# Maximum value in wet image 187: 255
# Maximum value in wet image 188: 255
# Maximum value in wet image 189: 255
# Maximum value in wet image 190: 255
# Maximum value in wet image 191: 255
# Maximum value in wet image 192: 255
# Maximum value in wet image 193: 255
# Maximum value in wet image 194: 255
# Maximum value in wet image 195: 255
# Maximum value in wet image 196: 255
# Maximum value in wet image 197: 255
# Maximum value in wet image 198: 255
# Maximum value in wet image 199: 255
# Maximum value in wet image 200: 255
# Maximum value in wet image 201: 255
# Maximum value in wet image 202: 255
# Maximum value in wet image 203: 255
# Maximum value in wet image 204: 255
# Maximum value in wet image 205: 255
# Maximum value in wet image 206: 255
# Maximum value in wet image 207: 255
# Maximum value in wet image 208: 255
# Maximum value in wet image 209: 255
# Maximum value in wet image 210: 255
# Maximum value in wet image 211: 255
# Maximum value in wet image 212: 255
# Maximum value in wet image 213: 255
# Maximum value in wet image 214: 255
# Maximum value in wet image 215: 255
# Maximum value in wet image 216: 255
# Maximum value in wet image 217: 255
# Maximum value in wet image 218: 255
# Maximum value in wet image 219: 255
# Maximum value in wet image 220: 255
# Maximum value in wet image 221: 255
# Maximum value in wet image 222: 255
# Maximum value in wet image 223: 255
# Maximum value in wet image 224: 255
# Maximum value in wet image 225: 255
# Maximum value in wet image 226: 252
# Maximum value in wet image 227: 255
# Maximum value in wet image 228: 255
# ['test', 'train', 'val']
# dry
# waste\train\dry\dry_waste (1).jpg
# waste\train\dry\dry_waste (10).jpg
# waste\train\dry\dry_waste (100).jpg
# waste\train\dry\dry_waste (101).jpg
# waste\train\dry\dry_waste (102).jpg
# waste\train\dry\dry_waste (103).JPG
# waste\train\dry\dry_waste (104).jpg
# waste\train\dry\dry_waste (105).jpg
# waste\train\dry\dry_waste (106).jpg
# waste\train\dry\dry_waste (107).jpg
# waste\train\dry\dry_waste (108).jpg
# waste\train\dry\dry_waste (109).jpg
# waste\train\dry\dry_waste (11).jpg
# waste\train\dry\dry_waste (110).jpg
# waste\train\dry\dry_waste (111).jpg
# waste\train\dry\dry_waste (112).jpg
# waste\train\dry\dry_waste (113).jpg
# waste\train\dry\dry_waste (114).jpg
# waste\train\wet\wet_waste (56).jpg
# waste\train\wet\wet_waste (57).jpg
# waste\train\wet\wet_waste (58).jpg
# waste\train\wet\wet_waste (59).jpg
# waste\train\wet\wet_waste (6).jpg
# waste\train\wet\wet_waste (60).jpg
# waste\train\wet\wet_waste (61).jpg
# waste\train\wet\wet_waste (62).jpg
# waste\train\wet\wet_waste (63).jpg
# waste\train\wet\wet_waste (64).jpg
# waste\train\wet\wet_waste (65).jpg
# waste\train\wet\wet_waste (66).jpg
# waste\train\wet\wet_waste (67).jpg
# waste\train\wet\wet_waste (68).jpg
# waste\train\wet\wet_waste (69).jpg
# waste\train\wet\wet_waste (7).jpg
# waste\train\wet\wet_waste (70).jpg
# waste\train\wet\wet_waste (71).jpg
# waste\train\wet\wet_waste (72).jpg
# waste\train\wet\wet_waste (73).jpg
# waste\train\wet\wet_waste (74).jpg
# waste\train\wet\wet_waste (75).jpg
# waste\train\wet\wet_waste (76).jpg
# waste\train\wet\wet_waste (77).jpg
# waste\train\wet\wet_waste (78).jpg
# waste\train\wet\wet_waste (79).jpg
# waste\train\wet\wet_waste (8).jpg
# waste\train\wet\wet_waste (80).jpg
# waste\train\wet\wet_waste (81).jpg
# waste\train\wet\wet_waste (82).jpg
# waste\train\wet\wet_waste (83).jpg
# waste\train\wet\wet_waste (84).jpg
# waste\train\wet\wet_waste (85).jpg
# waste\train\wet\wet_waste (86).jpg
# waste\train\wet\wet_waste (87).jpg
# waste\train\wet\wet_waste (88).jpg
# waste\train\wet\wet_waste (89).jpg
# waste\train\wet\wet_waste (90).jpg
# waste\train\wet\wet_waste (91).jpg
# waste\train\wet\wet_waste (92).jpg
# waste\train\wet\wet_waste (93).jpg
# waste\train\wet\wet_waste (94).jpg
# waste\train\wet\wet_waste (95).jpg
# waste\train\wet\wet_waste (96).jpg
# waste\train\wet\wet_waste (97).jpg
# waste\train\wet\wet_waste (98).jpg
# waste\train\wet\wet_waste (99).jpg
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_input (InputLayer)   [(None, 128, 128, 3)]     0
#
#  conv2d (Conv2D)             (None, 128, 128, 32)      896
#
#  batch_normalization (BatchN  (None, 128, 128, 32)     128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 32)      9248
#
#  batch_normalization_1 (Batc  (None, 128, 128, 32)     128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 64)        36928
#
#  batch_normalization_3 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense (Dense)               (None, 128)               8388736
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 8,455,330
# Trainable params: 8,454,946
# Non-trainable params: 384
# _________________________________________________________________
# None
# Epoch 1/50
# 12/12 [==============================] - 27s 2s/step - loss: 2.3794 - accuracy: 0.6316 - val_loss: 4.2072 - val_accuracy: 0.4138
# Epoch 2/50
# 12/12 [==============================] - 24s 2s/step - loss: 0.5147 - accuracy: 0.8532 - val_loss: 3.4043 - val_accuracy: 0.4138
# Epoch 3/50
# 12/12 [==============================] - 27s 2s/step - loss: 0.4308 - accuracy: 0.8283 - val_loss: 2.7132 - val_accuracy: 0.4138
# Epoch 4/50
# 12/12 [==============================] - 25s 2s/step - loss: 0.3252 - accuracy: 0.8698 - val_loss: 2.3931 - val_accuracy: 0.4138
# Epoch 5/50
# 12/12 [==============================] - 24s 2s/step - loss: 0.3375 - accuracy: 0.8670 - val_loss: 2.0487 - val_accuracy: 0.4138
# Epoch 6/50
# 12/12 [==============================] - 29s 2s/step - loss: 0.3554 - accuracy: 0.8393 - val_loss: 2.0260 - val_accuracy: 0.4138
# Epoch 7/50
# 12/12 [==============================] - 24s 2s/step - loss: 0.2875 - accuracy: 0.8837 - val_loss: 1.6344 - val_accuracy: 0.4138
# Epoch 8/50
# 12/12 [==============================] - 26s 2s/step - loss: 0.2805 - accuracy: 0.8837 - val_loss: 1.8357 - val_accuracy: 0.4138
# Epoch 9/50
# 12/12 [==============================] - 27s 2s/step - loss: 0.3087 - accuracy: 0.8615 - val_loss: 0.8868 - val_accuracy: 0.4138
# Epoch 10/50
# 12/12 [==============================] - 25s 2s/step - loss: 0.2458 - accuracy: 0.9003 - val_loss: 1.3050 - val_accuracy: 0.4138
# Epoch 11/50
# 12/12 [==============================] - 26s 2s/step - loss: 0.2343 - accuracy: 0.9141 - val_loss: 1.9067 - val_accuracy: 0.4138
# Epoch 12/50
# 12/12 [==============================] - 24s 2s/step - loss: 0.2317 - accuracy: 0.9003 - val_loss: 2.1508 - val_accuracy: 0.4138
# Epoch 13/50
# 12/12 [==============================] - 25s 2s/step - loss: 0.2712 - accuracy: 0.8753 - val_loss: 2.7850 - val_accuracy: 0.4138
# Epoch 14/50
# 12/12 [==============================] - 23s 2s/step - loss: 0.2067 - accuracy: 0.9252 - val_loss: 3.3349 - val_accuracy: 0.4138
# Epoch 15/50
# 12/12 [==============================] - 23s 2s/step - loss: 0.1896 - accuracy: 0.9252 - val_loss: 2.5567 - val_accuracy: 0.4483
# Epoch 16/50
# 12/12 [==============================] - 23s 2s/step - loss: 0.1930 - accuracy: 0.9169 - val_loss: 3.3689 - val_accuracy: 0.4483
# Epoch 17/50
# 12/12 [==============================] - 26s 2s/step - loss: 0.1862 - accuracy: 0.9307 - val_loss: 2.8743 - val_accuracy: 0.4483
# Epoch 18/50
# 12/12 [==============================] - 25s 2s/step - loss: 0.1875 - accuracy: 0.9363 - val_loss: 3.0987 - val_accuracy: 0.4483
# Epoch 19/50
# 12/12 [==============================] - 26s 2s/step - loss: 0.1950 - accuracy: 0.9224 - val_loss: 2.5757 - val_accuracy: 0.4828
# Epoch 20/50
# 12/12 [==============================] - 25s 2s/step - loss: 0.1809 - accuracy: 0.9252 - val_loss: 1.2453 - val_accuracy: 0.6207
# Epoch 21/50
# 12/12 [==============================] - 25s 2s/step - loss: 0.2077 - accuracy: 0.9224 - val_loss: 1.6544 - val_accuracy: 0.5862
# Epoch 22/50
# 12/12 [==============================] - 24s 2s/step - loss: 0.1578 - accuracy: 0.9612 - val_loss: 1.9336 - val_accuracy: 0.5862
# Epoch 23/50
# 12/12 [==============================] - 23s 2s/step - loss: 0.0712 - accuracy: 0.9834 - val_loss: 2.1438 - val_accuracy: 0.4828
# Epoch 44/50
# 12/12 [==============================] - 23s 2s/step - loss: 0.0677 - accuracy: 0.9834 - val_loss: 0.6695 - val_accuracy: 0.7241
# Epoch 45/50
# 12/12 [==============================] - 23s 2s/step - loss: 0.0655 - accuracy: 0.9806 - val_loss: 1.2147 - val_accuracy: 0.6552
# Epoch 46/50
# 12/12 [==============================] - 25s 2s/step - loss: 0.0744 - accuracy: 0.9806 - val_loss: 1.0569 - val_accuracy: 0.6552
# Epoch 47/50
# 12/12 [==============================] - 24s 2s/step - loss: 0.0589 - accuracy: 0.9861 - val_loss: 0.7310 - val_accuracy: 0.6552
# Epoch 48/50
# 12/12 [==============================] - 26s 2s/step - loss: 0.0511 - accuracy: 0.9861 - val_loss: 1.6351 - val_accuracy: 0.6207
# Epoch 49/50
# 12/12 [==============================] - 24s 2s/step - loss: 0.0663 - accuracy: 0.9751 - val_loss: 0.5346 - val_accuracy: 0.8966
# Epoch 50/50
# 12/12 [==============================] - 25s 2s/step - loss: 0.0387 - accuracy: 0.9861 - val_loss: 0.4512 - val_accuracy: 0.7931
# 1/1 [==============================] - 0s 496ms/step
# [[12  5]
#  [ 1 11]]
# 1/1 [==============================] - 0s 45ms/step
# The prediction for this image is:  ['dry']
# The actual label for this image is:  dry
# 12/12 [==============================] - 5s 409ms/step
# 1/1 [==============================] - 0s 331ms/step
# Accuracy =  0.7931034482758621
# 1/1 [==============================] - 0s 33ms/step
# The prediction for this image is:  ['dry']
# The actual label for this image is:  dry
# 1/1 [==============================] - 0s 105ms/step
# The prediction for this image is:  ['wet']
# The actual label for this image is:  dry

# %%
# test
test_images = []
test_labels = [] 
for directory_path in glob.glob("waste\\test\\*"):
    fruit_label = directory_path.split("\\")[-1]
    for img_path in glob.glob(os.path.join(directory_path, "*.jpg")):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)
        img = cv2.resize(img, (SIZE, SIZE))
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        test_images.append(img)
        test_labels.append(fruit_label)
        
test_images = np.array(test_images)
test_labels = np.array(test_labels)

#Encode labels from text to integers.
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(test_labels)
test_labels_encoded = le.transform(test_labels)
le.fit(train_labels)
train_labels_encoded = le.transform(train_labels)

#Split data into test and train datasets (already split but assigning to meaningful convention)
x_train, y_train, x_test, y_test = train_images, train_labels_encoded, test_images, test_labels_encoded
#Check results on a few select images
#n=5 #dog park. RF works better than CNN
n=random.randint(0,20) #Select the index of image to be loaded for testing
img = x_test[n]
plt.imshow(img)
input_img = np.expand_dims(img, axis=0) #Expand dims so the input is (num images, x, y, c)
input_img_features=feature_extractor.predict(input_img)
prediction_RF = loaded_model.predict(input_img_features)[0] 
prediction_RF = le.inverse_transform([prediction_RF])  #Reverse the label encoder to original name
print("The prediction for this image is: ", prediction_RF)
print("The actual label for this image is: ", test_labels[n])
# Out:
# 1/1 [==============================] - 0s 39ms/step
# The prediction for this image is:  ['wet']
# The actual label for this image is:  dry
